# %%
# a list can contain multiple data types (e.g. ints, floats, and strings)
list_x = [1,2,5,7,3,2.5,'test_string']

# %%
# they can even contain other lists (nested list)
list_y = [1 , 5 , 3.5 , [1,2,3]]

# %%
# or dictionaries
list_z = [5,3.0,'string', {'key1': 'value1'}]
type(list_z)

# %%
# we can pull specific values from a list by using [] and the list's name
list_x[1]  # pulls the second value, occurring at the first index (counting starts from 0)

# %%
# this logic means we may have to index multiple layers deep to get the value we're looking for (like the 2 in list_y)
list_y[3][1]

# %%
# let's take some integer x
x = 55
# recall from our work with ints, floats, etc. that there's a difference between temporarily modifying a variable's value...
print(x+1)
print(x)
# and resetting it
print('--')
x = x+1
print(x)
# similarly, we can modify values in lists / dictionaries:
print(list_x)
print(list_x[2])
print(list_x[2]+2)
list_x[2] = list_x[2]+2
print(list_x[2])

# %%
list_x

# %%
# we need to be careful about making defining objects that are equivalent to other objects (e.g. implicitly 'copying' list_x)
list_y = list_x

# %%
print(list_x,list_y)

# %%
# because if we modify the value from one list, it will also modify it in the other!
list_y[2] = list_y[2] - 50

# %%
list_y

# %%
list_x

# %%
# so if we want to avoid this behavior, we should have a genuine copy of the list
list_y = list_x.copy()

# %%
list_y[2] = list_y[2] - 50

# %%
list_y

# %%
list_x

# %%
# we can import -modules- basically the same as R packages. let's get one that deals with random number generation
# note that the word 'random' means nothing to Python by default: 
random
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 3>()
#       1 # we can import -modules- basically the same as R packages. let's get one that deals with random number generation
#       2 # note that the word 'random' means nothing to Python by default:
# ----> 3 random
#
# NameError: name 'random' is not defined

# %%
import random

# %%
random  #  this object is actually now referring to the module
# Out:
# <module 'random' from 'C:\\Users\\ethan\\anaconda3\\lib\\random.py'>

# %%
random.randint(0,10000)  # random integer between [0,10000]
# Out:
# 3008

# %%
x = random.randint(0,10000)

# %%
x
# Out:
# 1489

# %%
while True:  #sidebar: this loop will go forever; you'll see a grey dot in the top right corner next to (ipykernel)
    print('eternal')  # press the square button next to Run to stop it!

# %%
# for n in range(0,1000)   ...  "for every integer n in [0,1000)"

# while   ...  "while something is true, do something"

# %%
help(random.randint)  # we can get the documentation on any object with help:
# Out:
# Help on method randint in module random:
#
# randint(a, b) method of random.Random instance
#     Return random integer in range [a, b], including both end points.

# %%
our_data = []  # instantiate an empty list

# %%
print(our_data, type(our_data))
# Out:
# [] <class 'list'>

# %%
'''1.) generate random integers using random.randint(0,100), 100000
3.) store all of the random numbers that we generate.'''

# %%
counter = 0
dataset = []
while True:
    x = random.randint(0,100)
    print(x)
    dataset.append(x)
    
    # if x == 100:
    #     print(x)
    #     break
    
    counter = counter+1
    if counter >= 100000:
        break
# Out:
# 34
# 98
# 92
# 29
# 35
# 14
# 34
# 83
# 89
# 12
# 97
# 44
# 8
# 92
# 2
# 30
# 35
# 81
# 89
# 81
# 86
# 71
# 0
# 97
# 32
# 46
# 25
# 11
# 89
# 29
# 94
# 89
# 75
# 26
# 24
# 94
# 4
# 8
# 86
# 4
# 55
# 19
# 54
# 86
# 89
# 21
# 51
# 87
# 81
# 75
# 33
# 79
# 96
# 20
# 63
# 82
# 89
# 42
# 9
# 60
# 12
# 14
# 30
# 57
# 39
# 29
# 40
# 20
# 39
# 10
# 95
# 15
# 93
# 51
# 86
# 82
# 93
# 78
# 1
# 10
# 49
# 29
# 74
# 62
# 87
# 8
# 43
# 55
# 56
# 85
# 100
# 41
# 26
# 65
# 17
# 91
# 43
# 6
# 67
# 51
# 40
# 54
# 88
# 32
# 22
# 27
# 77
# 26
# 20
# 74
# 73
# 81
# 15
# 35
# 48
# 96
# 36
# 88
# 40
# 48
# 85
# 44
# 66
# 57
# 13
# 53
# 62
# 71
# 8
# 98
# 7
# 17
# 65
# 49
# 56
# 80
# 10
# 24
# 61
# 52
# 27
# 38
# 61
# 81
# 81
# 20
# 74
# 20
# 17
# 44
# 77
# 22
# 98
# 96
# 61
# 9
# 48
# 80
# 43
# 97
# 25
# 15
# 26
# 7
# 24
# 65
# 18
# 78
# 80
# 67
# 7
# 87
# 82
# 72
# 85
# 6
# 3
# 81
# 26
# 25
# 33
# 69
# 8
# 12
# 85
# 93
# 42
# 99
# 87
# 31
# 62
# 23
# 58
# 64
# 69
# 54
# 17
# 7
# 95
# 13
# 9
# 97
# 23
# ...

# %%
print()

# %%
'''We want to create a function that:
1.) allows us to pick the maximum number for the randint generation
2.) allows us to pick the # of simulations / draws
3.) stores the draws in a dataset
4.) and outputs the result as a histogram, with the correct number of bins'''

# %%
import seaborn as sns  # sns is an alias for seaborn; you can call it whatever you like by sns is the norm

# %%
def generate_randint_distribution(maximum_num, num_draws):
    '''maximum_num is the maximum number that x can take.
    num_draws is the number of times to repeat the while loop.'''
    
    # argument tests.
    # check to see that maximum_num is an integer
    if not isinstance(maximum_num, int):
        raise ValueError('maximum_num needs to be an integer.')
    if not isinstance(num_draws, int):
        raise ValueError('num_draws needs to be an integer.')
    counter = 0
    dataset = []
    while True:
        x = random.randint(0,maximum_num)
        # print(x)
        dataset.append(x)

        # if x == 100:
        #     print(x)
        #     break

        counter = counter+1
        if counter >= num_draws:
            break
    sns.histplot(data=dataset,  bins=maximum_num+1)

# %%
type(5)
# Out:
# int

# %%
type('five')
# Out:
# str

# %%
isinstance(5.0, int)
# Out:
# False

# %%
type(generate_randint_distribution)
# Out:
# function

# %%
raise ValueError('this is my value error!')  # we can force an error to occur - good for providing the user useful feedback
print('hello!')  # this line wont print
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [29], in <cell line: 1>()
# ----> 1 raise ValueError('this is my value error!')  # we can force an error to occur - good for providing the user useful feedback
#       2 print('hello!')
#
# ValueError: this is my value error!

# %%
generate_randint_distribution(100, 5000)

# %%
generate_randint_distribution()  # will raise an error; we're missing two required arguments
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [31], in <cell line: 1>()
# ----> 1 generate_randint_distribution()
#
# TypeError: generate_randint_distribution() missing 2 required positional arguments: 'maximum_num' and 'num_draws'

# %%
len(dataset)
# Out:
# 100000
